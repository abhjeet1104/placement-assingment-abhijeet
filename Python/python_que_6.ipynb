# %%
# Importing Libraries:

import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading data from question 3: 

path = "/home/omkar/Omkar Pawar/Data Science/Placement Assignment Omkar Pawar/Python/pokemon.xlsx"
pokemon = pd.read_excel(path)

pokemon.head()
# Out:
#    id  num        name                                               img
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy  candy_count
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# 0         2 km         0.690        69.0      20:00      [1.58]  \
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
# 2  Not in Eggs         0.017         1.7      11:30         NaN
# 3         2 km         0.253        25.3      08:45      [1.65]
# 4  Not in Eggs         0.012         1.2      19:00      [1.79]
#
#                              weaknesses
# 0  ['Fire', 'Ice', 'Flying', 'Psychic']  \
# 1  ['Fire', 'Ice', 'Flying', 'Psychic']
# 2  ['Fire', 'Ice', 'Flying', 'Psychic']
# 3           ['Water', 'Ground', 'Rock']
# 4           ['Water', 'Ground', 'Rock']
#
#                                       next_evolution
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  \
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                                NaN
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]
#
#                                       prev_evolution
# 0                                                NaN
# 1              [{'num': '001', 'name': 'Bulbasaur'}]
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                NaN
# 4             [{'num': '004', 'name': 'Charmander'}]

# %%
df = pokemon

# %% [markdown]
# # Task 1: Get all Pokemons whose spawn rate is less than 5%

# %%
df['spawn_time'].isnull().sum() # there are 6 null values
# Out:
# 6

# %%
# converting spawn time in minutes format:
temp_df = df['spawn_time'].str.split(":")
df["spawn_min"] = None
for i in range(len(temp_df)):
    if pd.isnull(df["spawn_time"][i]):
        continue
    else:
        # df['spawn_min'] = 0
        df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# Out:
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])
# /tmp/ipykernel_6945/1629924649.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_min'][i] = (int(temp_df[i][0])*60) + int(temp_df[i][1])

# %%
df.head()
# Out:
#    id  num        name                                               img
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy  candy_count
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# 0         2 km         0.690        69.0      20:00      [1.58]  \
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
# 2  Not in Eggs         0.017         1.7      11:30         NaN
# 3         2 km         0.253        25.3      08:45      [1.65]
# 4  Not in Eggs         0.012         1.2      19:00      [1.79]
#
#                              weaknesses
# 0  ['Fire', 'Ice', 'Flying', 'Psychic']  \
# 1  ['Fire', 'Ice', 'Flying', 'Psychic']
# 2  ['Fire', 'Ice', 'Flying', 'Psychic']
# 3           ['Water', 'Ground', 'Rock']
# 4           ['Water', 'Ground', 'Rock']
#
#                                       next_evolution
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  \
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                                NaN
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]
#
#                                       prev_evolution spawn_min
# 0                                                NaN      1200
# 1              [{'num': '001', 'name': 'Bulbasaur'}]       420
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...       690
# 3                                                NaN       525
# 4             [{'num': '004', 'name': 'Charmander'}]      1140

# %%
import pandas as pd
df["spawn_rate"] = None 
for i in range(len(df)):
    if pd.isnull(df["spawn_min"][i]):
        continue
    else:
        df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# Out:
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])
# /tmp/ipykernel_6945/1276101078.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spawn_rate'][i] = (df['spawn_chance'][i] * (df['avg_spawns'][i]) * 100) / int(df['spawn_min'][i])

# %%
df.head()
# Out:
#    id  num        name                                               img
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy  candy_count
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# 0         2 km         0.690        69.0      20:00      [1.58]  \
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
# 2  Not in Eggs         0.017         1.7      11:30         NaN
# 3         2 km         0.253        25.3      08:45      [1.65]
# 4  Not in Eggs         0.012         1.2      19:00      [1.79]
#
#                              weaknesses
# 0  ['Fire', 'Ice', 'Flying', 'Psychic']  \
# 1  ['Fire', 'Ice', 'Flying', 'Psychic']
# 2  ['Fire', 'Ice', 'Flying', 'Psychic']
# 3           ['Water', 'Ground', 'Rock']
# 4           ['Water', 'Ground', 'Rock']
#
#                                       next_evolution
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  \
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                                NaN
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]
#
#                                       prev_evolution spawn_min spawn_rate
# 0                                                NaN      1200     3.9675
# 1              [{'num': '001', 'name': 'Bulbasaur'}]       420      0.042
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...       690   0.004188
# 3                                                NaN       525   1.219219
# 4             [{'num': '004', 'name': 'Charmander'}]      1140   0.001263

# %%
# final result:
df[df["spawn_rate"] < 5]
# Out:
#       id  num        name                                               img
# 0      1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...         ...                                               ...
# 141  142  142  Aerodactyl  http://www.serebii.net/pokemongo/pokemon/142.png
# 142  143  143     Snorlax  http://www.serebii.net/pokemongo/pokemon/143.png
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
#
#                      type  height    weight             candy  candy_count
# 0     ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1     ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2     ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3                ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4                ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
# ..                    ...     ...       ...               ...          ...
# 141    ['Rock', 'Flying']  1.80 m   59.0 kg               NaN          NaN
# 142            ['Normal']  2.11 m  460.0 kg               NaN          NaN
# 146            ['Dragon']  1.80 m    3.3 kg     Dratini Candy         25.0
# 147            ['Dragon']  3.99 m   16.5 kg     Dratini Candy        100.0
# 148  ['Dragon', 'Flying']  2.21 m  210.0 kg     Dratini Candy          NaN
#
#              egg  spawn_chance  avg_spawns spawn_time
# 0           2 km        0.6900       69.00      20:00  \
# 1    Not in Eggs        0.0420        4.20      07:00
# 2    Not in Eggs        0.0170        1.70      11:30
# 3           2 km        0.2530       25.30      08:45
# 4    Not in Eggs        0.0120        1.20      19:00
# ..           ...           ...         ...        ...
# 141        10 km        0.0180        1.80      23:40
# 142        10 km        0.0160        1.60      23:40
# 146        10 km        0.3000       30.00      06:41
# 147  Not in Eggs        0.0200        2.00      11:57
# 148  Not in Eggs        0.0011        0.11      23:38
#
#                     multipliers
# 0                        [1.58]  \
# 1                    [1.2, 1.6]
# 2                           NaN
# 3                        [1.65]
# 4                        [1.79]
# ..                          ...
# 141                         NaN
# 142                         NaN
# 146  [1.83, 1.8399999999999999]
# 147                      [2.05]
# 148                         NaN
#
#                                         weaknesses
# 0             ['Fire', 'Ice', 'Flying', 'Psychic']  \
# 1             ['Fire', 'Ice', 'Flying', 'Psychic']
# 2             ['Fire', 'Ice', 'Flying', 'Psychic']
# 3                      ['Water', 'Ground', 'Rock']
# 4                      ['Water', 'Ground', 'Rock']
# ..                                             ...
# 141  ['Water', 'Electric', 'Ice', 'Rock', 'Steel']
# 142                                   ['Fighting']
# 146                     ['Ice', 'Dragon', 'Fairy']
# 147                     ['Ice', 'Dragon', 'Fairy']
# 148             ['Ice', 'Rock', 'Dragon', 'Fairy']
#
#                                         next_evolution
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  \
# 1                 [{'num': '003', 'name': 'Venusaur'}]
# 2                                                  NaN
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4                [{'num': '006', 'name': 'Charizard'}]
# ..                                                 ...
# 141                                                NaN
# 142                                                NaN
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...
# 147              [{'num': '149', 'name': 'Dragonite'}]
# 148                                                NaN
#
#                                         prev_evolution spawn_min spawn_rate
# 0                                                  NaN      1200     3.9675
# 1                [{'num': '001', 'name': 'Bulbasaur'}]       420      0.042
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...       690   0.004188
# 3                                                  NaN       525   1.219219
# 4               [{'num': '004', 'name': 'Charmander'}]      1140   0.001263
# ..                                                 ...       ...        ...
# 141                                                NaN      1420   0.002282
# 142                                                NaN      1420   0.001803
# 146                                                NaN       401   2.244389
# 147                [{'num': '147', 'name': 'Dratini'}]       717   0.005579
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...      1418   0.000009
#
# [96 rows x 19 columns]

# %% [markdown]
# -----

# %% [markdown]
# # Task 2: Get all Pokemons that have less than 4 weaknesses:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              151 non-null    int64
#  1   num             151 non-null    int64
#  2   name            151 non-null    object
#  3   img             151 non-null    object
#  4   type            151 non-null    object
#  5   height          151 non-null    object
#  6   weight          151 non-null    object
#  7   candy           124 non-null    object
#  8   candy_count     70 non-null     float64
#  9   egg             151 non-null    object
#  10  spawn_chance    151 non-null    float64
#  11  avg_spawns      151 non-null    float64
#  12  spawn_time      145 non-null    object
#  13  multipliers     70 non-null     object
#  14  weaknesses      151 non-null    object
#  15  next_evolution  70 non-null     object
#  16  prev_evolution  72 non-null     object
#  17  spawn_min       145 non-null    object
#  18  spawn_rate      145 non-null    object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 22.5+ KB

# %%
import pandas as pd
import ast

df['weaknesses'] = df['weaknesses'].apply(ast.literal_eval) # it changes object to list 

df['weaknesses'].apply(len)
# Out:
# 0      4
# 1      4
# 2      4
# 3      3
# 4      3
#       ..
# 146    3
# 147    3
# 148    4
# 149    3
# 150    3
# Name: weaknesses, Length: 151, dtype: int64

# %%
# final Result:
weakness_threshold = 4
pokemon_with_less_than_4_weaknesses = pokemon[df['weaknesses'].apply(len) < weakness_threshold]
pokemon_with_less_than_4_weaknesses[['num', 'name', 'weaknesses']]
# Out:
#      num        name               weaknesses
# 3      4  Charmander    [Water, Ground, Rock]
# 4      5  Charmeleon    [Water, Ground, Rock]
# 5      6   Charizard  [Water, Electric, Rock]
# 6      7    Squirtle        [Electric, Grass]
# 7      8   Wartortle        [Electric, Grass]
# ..   ...         ...                      ...
# 145  146     Moltres  [Water, Electric, Rock]
# 146  147     Dratini     [Ice, Dragon, Fairy]
# 147  148   Dragonair     [Ice, Dragon, Fairy]
# 149  150      Mewtwo       [Bug, Ghost, Dark]
# 150  151         Mew       [Bug, Ghost, Dark]
#
# [102 rows x 3 columns]

# %% [markdown]
# ----

# %% [markdown]
# ### Task 3: Get all Pokemons that have no multipliers at all

# %%
df[df["multipliers"].isnull()]
# Out:
#       id  num        name                                               img
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png  \
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 8      9    9   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 11    12   12  Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# 14    15   15    Beedrill  http://www.serebii.net/pokemongo/pokemon/015.png
# ..   ...  ...         ...                                               ...
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                        type  height    weight             candy  candy_count
# 2       ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN  \
# 5        ['Fire', 'Flying']  1.70 m   90.5 kg  Charmander Candy          NaN
# 8                 ['Water']  1.60 m   85.5 kg    Squirtle Candy          NaN
# 11        ['Bug', 'Flying']  1.09 m   32.0 kg    Caterpie Candy          NaN
# 14        ['Bug', 'Poison']  0.99 m   29.5 kg      Weedle Candy          NaN
# ..                      ...     ...       ...               ...          ...
# 144  ['Electric', 'Flying']  1.60 m   52.6 kg               NaN          NaN
# 145      ['Fire', 'Flying']  2.01 m   60.0 kg               NaN          NaN
# 148    ['Dragon', 'Flying']  2.21 m  210.0 kg     Dratini Candy          NaN
# 149             ['Psychic']  2.01 m  122.0 kg               NaN          NaN
# 150             ['Psychic']  0.41 m    4.0 kg               NaN          NaN
#
#              egg  spawn_chance  avg_spawns spawn_time multipliers
# 2    Not in Eggs        0.0170        1.70      11:30         NaN  \
# 5    Not in Eggs        0.0031        0.31      13:34         NaN
# 8    Not in Eggs        0.0067        0.67      00:06         NaN
# 11   Not in Eggs        0.0220        2.20      05:23         NaN
# 14   Not in Eggs        0.0510        5.10      04:50         NaN
# ..           ...           ...         ...        ...         ...
# 144  Not in Eggs        0.0000        0.00        NaN         NaN
# 145  Not in Eggs        0.0000        0.00        NaN         NaN
# 148  Not in Eggs        0.0011        0.11      23:38         NaN
# 149  Not in Eggs        0.0000        0.00        NaN         NaN
# 150  Not in Eggs        0.0000        0.00        NaN         NaN
#
#                               weaknesses next_evolution
# 2           [Fire, Ice, Flying, Psychic]            NaN  \
# 5                [Water, Electric, Rock]            NaN
# 8                      [Electric, Grass]            NaN
# 11   [Fire, Electric, Ice, Flying, Rock]            NaN
# 14         [Fire, Flying, Psychic, Rock]            NaN
# ..                                   ...            ...
# 144                          [Ice, Rock]            NaN
# 145              [Water, Electric, Rock]            NaN
# 148           [Ice, Rock, Dragon, Fairy]            NaN
# 149                   [Bug, Ghost, Dark]            NaN
# 150                   [Bug, Ghost, Dark]            NaN
#
#                                         prev_evolution spawn_min spawn_rate
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...       690   0.004188
# 5    [{'num': '004', 'name': 'Charmander'}, {'num':...       814   0.000118
# 8    [{'num': '007', 'name': 'Squirtle'}, {'num': '...         6   0.074817
# 11   [{'num': '010', 'name': 'Caterpie'}, {'num': '...       323   0.014985
# 14   [{'num': '013', 'name': 'Weedle'}, {'num': '01...       290    0.08969
# ..                                                 ...       ...        ...
# 144                                                NaN      None       None
# 145                                                NaN      None       None
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...      1418   0.000009
# 149                                                NaN      None       None
# 150                                                NaN      None       None
#
# [81 rows x 19 columns]

# %% [markdown]
# ----

# %% [markdown]
# ### Task 4: Get all Pokemons that do not have more than 2 evolutions

# %%
df.head()
# Out:
#    id  num        name                                               img
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy  candy_count
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers
# 0         2 km         0.690        69.0      20:00      [1.58]  \
# 1  Not in Eggs         0.042         4.2      07:00  [1.2, 1.6]
# 2  Not in Eggs         0.017         1.7      11:30         NaN
# 3         2 km         0.253        25.3      08:45      [1.65]
# 4  Not in Eggs         0.012         1.2      19:00      [1.79]
#
#                      weaknesses
# 0  [Fire, Ice, Flying, Psychic]  \
# 1  [Fire, Ice, Flying, Psychic]
# 2  [Fire, Ice, Flying, Psychic]
# 3         [Water, Ground, Rock]
# 4         [Water, Ground, Rock]
#
#                                       next_evolution
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  \
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                                NaN
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]
#
#                                       prev_evolution spawn_min spawn_rate
# 0                                                NaN      1200     3.9675
# 1              [{'num': '001', 'name': 'Bulbasaur'}]       420      0.042
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...       690   0.004188
# 3                                                NaN       525   1.219219
# 4             [{'num': '004', 'name': 'Charmander'}]      1140   0.001263

# %%
pokemon_without_candy = df[df['candy'].isnull()]
pokemon_without_candy
# Out:
#       id  num        name                                               img
# 82    83   83  Farfetch'd  http://www.serebii.net/pokemongo/pokemon/083.png  \
# 94    95   95        Onix  http://www.serebii.net/pokemongo/pokemon/095.png
# 105  106  106   Hitmonlee  http://www.serebii.net/pokemongo/pokemon/106.png
# 106  107  107  Hitmonchan  http://www.serebii.net/pokemongo/pokemon/107.png
# 107  108  108   Lickitung  http://www.serebii.net/pokemongo/pokemon/108.png
# 112  113  113     Chansey  http://www.serebii.net/pokemongo/pokemon/113.png
# 113  114  114     Tangela  http://www.serebii.net/pokemongo/pokemon/114.png
# 114  115  115  Kangaskhan  http://www.serebii.net/pokemongo/pokemon/115.png
# 121  122  122    Mr. Mime  http://www.serebii.net/pokemongo/pokemon/122.png
# 122  123  123     Scyther  http://www.serebii.net/pokemongo/pokemon/123.png
# 123  124  124        Jynx  http://www.serebii.net/pokemongo/pokemon/124.png
# 124  125  125  Electabuzz  http://www.serebii.net/pokemongo/pokemon/125.png
# 125  126  126      Magmar  http://www.serebii.net/pokemongo/pokemon/126.png
# 126  127  127      Pinsir  http://www.serebii.net/pokemongo/pokemon/127.png
# 127  128  128      Tauros  http://www.serebii.net/pokemongo/pokemon/128.png
# 130  131  131      Lapras  http://www.serebii.net/pokemongo/pokemon/131.png
# 131  132  132       Ditto  http://www.serebii.net/pokemongo/pokemon/132.png
# 134  135  135     Jolteon  http://www.serebii.net/pokemongo/pokemon/135.png
# 136  137  137     Porygon  http://www.serebii.net/pokemongo/pokemon/137.png
# 138  139  139     Omastar  http://www.serebii.net/pokemongo/pokemon/139.png
# 141  142  142  Aerodactyl  http://www.serebii.net/pokemongo/pokemon/142.png
# 142  143  143     Snorlax  http://www.serebii.net/pokemongo/pokemon/143.png
# 143  144  144    Articuno  http://www.serebii.net/pokemongo/pokemon/144.png
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                        type  height    weight candy  candy_count
# 82     ['Normal', 'Flying']  0.79 m   15.0 kg   NaN          NaN  \
# 94       ['Rock', 'Ground']  8.79 m  210.0 kg   NaN          NaN
# 105            ['Fighting']  1.50 m   49.8 kg   NaN          NaN
# 106            ['Fighting']  1.40 m   50.2 kg   NaN          NaN
# 107              ['Normal']  1.19 m   65.5 kg   NaN          NaN
# 112              ['Normal']  1.09 m   34.6 kg   NaN          NaN
# 113               ['Grass']  0.99 m   35.0 kg   NaN          NaN
# 114              ['Normal']  2.21 m   80.0 kg   NaN          NaN
# 121             ['Psychic']  1.30 m   54.5 kg   NaN          NaN
# 122       ['Bug', 'Flying']  1.50 m   56.0 kg   NaN          NaN
# 123      ['Ice', 'Psychic']  1.40 m   40.6 kg   NaN          NaN
# 124            ['Electric']  1.09 m   30.0 kg   NaN          NaN
# 125                ['Fire']  1.30 m   44.5 kg   NaN          NaN
# 126                 ['Bug']  1.50 m   55.0 kg   NaN          NaN
# 127              ['Normal']  1.40 m   88.4 kg   NaN          NaN
# 130        ['Water', 'Ice']  2.49 m  220.0 kg   NaN          NaN
# 131              ['Normal']  0.30 m    4.0 kg   NaN          NaN
# 134            ['Electric']  0.79 m   24.5 kg   NaN          NaN
# 136              ['Normal']  0.79 m   36.5 kg   NaN          NaN
# 138       ['Rock', 'Water']  0.99 m   35.0 kg   NaN          NaN
# 141      ['Rock', 'Flying']  1.80 m   59.0 kg   NaN          NaN
# 142              ['Normal']  2.11 m  460.0 kg   NaN          NaN
# 143       ['Ice', 'Flying']  1.70 m   55.4 kg   NaN          NaN
# 144  ['Electric', 'Flying']  1.60 m   52.6 kg   NaN          NaN
# 145      ['Fire', 'Flying']  2.01 m   60.0 kg   NaN          NaN
# 149             ['Psychic']  2.01 m  122.0 kg   NaN          NaN
# 150             ['Psychic']  0.41 m    4.0 kg   NaN          NaN
#
#                egg  spawn_chance  avg_spawns spawn_time multipliers
# 82            5 km        0.0212        2.12      01:09         NaN  \
# 94           10 km        0.1000       10.00      01:18         NaN
# 105          10 km        0.0200        2.00      03:59         NaN
# 106          10 km        0.0220        2.20      05:58         NaN
# 107           5 km        0.0110        1.10      02:46         NaN
# 112          10 km        0.0130        1.30      04:46         NaN
# 113           5 km        0.2280       22.80      23:13         NaN
# 114           5 km        0.0086        0.86      02:40         NaN
# 121          10 km        0.0031        0.31      01:51         NaN
# 122          10 km        0.1400       14.00      05:43         NaN
# 123          10 km        0.3500       35.00      05:41         NaN
# 124          10 km        0.0740        7.40      04:28         NaN
# 125          10 km        0.1000       10.00      20:36         NaN
# 126          10 km        0.9900       99.00      03:25         NaN
# 127           5 km        0.1200       12.00      00:37         NaN
# 130          10 km        0.0060        0.60      08:59         NaN
# 131    Not in Eggs        0.0000        0.00        NaN         NaN
# 134    Not in Eggs        0.0120        1.20      02:30         NaN
# 136           5 km        0.0120        1.20      02:49         NaN
# 138  Omanyte Candy        0.0061        0.61      05:04         NaN
# 141          10 km        0.0180        1.80      23:40         NaN
# 142          10 km        0.0160        1.60      23:40         NaN
# 143    Not in Eggs        0.0000        0.00        NaN         NaN
# 144    Not in Eggs        0.0000        0.00        NaN         NaN
# 145    Not in Eggs        0.0000        0.00        NaN         NaN
# 149    Not in Eggs        0.0000        0.00        NaN         NaN
# 150    Not in Eggs        0.0000        0.00        NaN         NaN
#
#                                        weaknesses next_evolution
# 82                               [Electric, Rock]            NaN  \
# 94   [Water, Grass, Ice, Fighting, Ground, Steel]            NaN
# 105                      [Flying, Psychic, Fairy]            NaN
# 106                      [Flying, Psychic, Fairy]            NaN
# 107                                    [Fighting]            NaN
# 112                                    [Fighting]            NaN
# 113              [Fire, Ice, Poison, Flying, Bug]            NaN
# 114                                    [Fighting]            NaN
# 121                            [Bug, Ghost, Dark]            NaN
# 122           [Fire, Electric, Ice, Flying, Rock]            NaN
# 123         [Fire, Bug, Rock, Ghost, Dark, Steel]            NaN
# 124                                      [Ground]            NaN
# 125                         [Water, Ground, Rock]            NaN
# 126                          [Fire, Flying, Rock]            NaN
# 127                                    [Fighting]            NaN
# 130             [Electric, Grass, Fighting, Rock]            NaN
# 131                                    [Fighting]            NaN
# 134                                      [Ground]            NaN
# 136                                    [Fighting]            NaN
# 138           [Electric, Grass, Fighting, Ground]            NaN
# 141           [Water, Electric, Ice, Rock, Steel]            NaN
# 142                                    [Fighting]            NaN
# 143                 [Fire, Electric, Rock, Steel]            NaN
# 144                                   [Ice, Rock]            NaN
# 145                       [Water, Electric, Rock]            NaN
# 149                            [Bug, Ghost, Dark]            NaN
# 150                            [Bug, Ghost, Dark]            NaN
#
#                           prev_evolution spawn_min spawn_rate
# 82                                   NaN        69   0.065136
# 94                                   NaN        78   1.282051
# 105                                  NaN       239   0.016736
# 106                                  NaN       358    0.01352
# 107                                  NaN       166   0.007289
# 112                                  NaN       286   0.005909
# 113                                  NaN      1393    0.37318
# 114                                  NaN       160   0.004622
# 121                                  NaN       111   0.000866
# 122                                  NaN       343   0.571429
# 123                                  NaN       341   3.592375
# 124                                  NaN       268   0.204328
# 125                                  NaN      1236   0.080906
# 126                                  NaN       205  47.809756
# 127                                  NaN        37   3.891892
# 130                                  NaN       539   0.000668
# 131                                  NaN      None       None
# 134    [{'num': '133', 'name': 'Eevee'}]       150     0.0096
# 136                                  NaN       169   0.008521
# 138  [{'num': '138', 'name': 'Omanyte'}]       304   0.001224
# 141                                  NaN      1420   0.002282
# 142                                  NaN      1420   0.001803
# 143                                  NaN      None       None
# 144                                  NaN      None       None
# 145                                  NaN      None       None
# 149                                  NaN      None       None
# 150                                  NaN      None       None

# %%
list_of_pokemons = df['candy'].unique()
list_of_pokemons
# Out:
# array(['Bulbasaur Candy', 'Charmander Candy', 'Squirtle Candy',
#        'Caterpie Candy', 'Weedle Candy', 'Pidgey Candy', 'Rattata Candy',
#        'Spearow Candy', 'Ekans Candy', 'Pikachu Candy', 'Sandshrew Candy',
#        'Nidoran ♀ (Female) Candy', 'Nidoran ♂ (Male) Candy',
#        'Clefairy Candy', 'Vulpix Candy', 'Jigglypuff Candy',
#        'Zubat Candy', 'Oddish Candy', 'Paras Candy', 'Venonat Candy',
#        'Diglett Candy', 'Dugtrio', 'Meowth Candy', 'Psyduck Candy',
#        'Mankey Candy', 'Growlithe Candy', 'Poliwag Candy', 'Abra Candy',
#        'Machop Candy', 'Bellsprout Candy', 'Tentacool Candy',
#        'Geodude Candy', 'Ponyta Candy', 'Slowpoke Candy',
#        'Magnemite Candy', nan, 'Doduo Candy', 'Seel Candy',
#        'Grimer Candy', 'Shellder Candy', 'Gastly Candy', 'Drowzee Candy',
#        'Krabby Candy', 'Voltorb Candy', 'Exeggcute Candy', 'Cubone Candy',
#        'Koffing Candy', 'Rhyhorn Candy', 'Horsea Candy', 'Goldeen Candy',
#        'Staryu Candy', 'Magikarp Candy', 'Eevee Candy', 'Omanyte Candy',
#        'Kabuto Candy', 'Dratini Candy'], dtype=object)

# %%
pokemon_with_evolution = df['candy'].value_counts().to_dict()

# %%
pokemon_with_evolution
# Out:
# {'Bulbasaur Candy': 3,
#  'Nidoran ♀ (Female) Candy': 3,
#  'Eevee Candy': 3,
#  'Gastly Candy': 3,
#  'Geodude Candy': 3,
#  'Bellsprout Candy': 3,
#  'Machop Candy': 3,
#  'Charmander Candy': 3,
#  'Poliwag Candy': 3,
#  'Oddish Candy': 3,
#  'Nidoran ♂ (Male) Candy': 3,
#  'Abra Candy': 3,
#  'Dratini Candy': 3,
#  'Squirtle Candy': 3,
#  'Weedle Candy': 3,
#  'Pidgey Candy': 3,
#  'Caterpie Candy': 3,
#  'Voltorb Candy': 2,
#  'Seel Candy': 2,
#  'Grimer Candy': 2,
#  'Shellder Candy': 2,
#  'Drowzee Candy': 2,
#  'Krabby Candy': 2,
#  'Exeggcute Candy': 2,
#  'Magnemite Candy': 2,
#  'Cubone Candy': 2,
#  'Koffing Candy': 2,
#  'Rhyhorn Candy': 2,
#  'Horsea Candy': 2,
#  'Goldeen Candy': 2,
#  'Staryu Candy': 2,
#  'Magikarp Candy': 2,
#  'Kabuto Candy': 2,
#  'Doduo Candy': 2,
#  'Sandshrew Candy': 2,
#  'Clefairy Candy': 2,
#  'Meowth Candy': 2,
#  'Vulpix Candy': 2,
#  'Jigglypuff Candy': 2,
#  'Zubat Candy': 2,
#  'Pikachu Candy': 2,
#  'Paras Candy': 2,
#  'Venonat Candy': 2,
#  'Ponyta Candy': 2,
#  'Slowpoke Candy': 2,
#  'Psyduck Candy': 2,
#  'Mankey Candy': 2,
#  'Growlithe Candy': 2,
#  'Ekans Candy': 2,
#  'Spearow Candy': 2,
#  'Rattata Candy': 2,
#  'Tentacool Candy': 2,
#  'Diglett Candy': 1,
#  'Omanyte Candy': 1,
#  'Dugtrio': 1}

# %%
type(pokemon_with_evolution)
# Out:
# dict

# %%
pokemon_with_eval_greater_than_2 = []
pokemon_with_eval_less_than_2 = []
for k, v in pokemon_with_evolution.items():
    name = k.split()[0]
    if v > 3:
        pokemon_with_eval_greater_than_2.append(name)  
    else:
        pokemon_with_eval_less_than_2.append(name)

print("pokemon who have less than 2 evolutions", pokemon_with_eval_less_than_2)
print("-----------")
print("pokemon who have more than 2 evolutions", pokemon_with_eval_greater_than_2)
# Out:
# pokemon who have less than 2 evolutions ['Bulbasaur', 'Nidoran', 'Eevee', 'Gastly', 'Geodude', 'Bellsprout', 'Machop', 'Charmander', 'Poliwag', 'Oddish', 'Nidoran', 'Abra', 'Dratini', 'Squirtle', 'Weedle', 'Pidgey', 'Caterpie', 'Voltorb', 'Seel', 'Grimer', 'Shellder', 'Drowzee', 'Krabby', 'Exeggcute', 'Magnemite', 'Cubone', 'Koffing', 'Rhyhorn', 'Horsea', 'Goldeen', 'Staryu', 'Magikarp', 'Kabuto', 'Doduo', 'Sandshrew', 'Clefairy', 'Meowth', 'Vulpix', 'Jigglypuff', 'Zubat', 'Pikachu', 'Paras', 'Venonat', 'Ponyta', 'Slowpoke', 'Psyduck', 'Mankey', 'Growlithe', 'Ekans', 'Spearow', 'Rattata', 'Tentacool', 'Diglett', 'Omanyte', 'Dugtrio']
# -----------
# pokemon who have more than 2 evolutions []

# %% [markdown]
# pokemon with more than two evolutions does not exist.

# %%
# if we consider null values as no evolution then: 

list(pokemon_without_candy['name'])
# Out:
# ["Farfetch'd",
#  'Onix',
#  'Hitmonlee',
#  'Hitmonchan',
#  'Lickitung',
#  'Chansey',
#  'Tangela',
#  'Kangaskhan',
#  'Mr. Mime',
#  'Scyther',
#  'Jynx',
#  'Electabuzz',
#  'Magmar',
#  'Pinsir',
#  'Tauros',
#  'Lapras',
#  'Ditto',
#  'Jolteon',
#  'Porygon',
#  'Omastar',
#  'Aerodactyl',
#  'Snorlax',
#  'Articuno',
#  'Zapdos',
#  'Moltres',
#  'Mewtwo',
#  'Mew']

# %%
pokemon_with_eval_less_than_2.extend(list(pokemon_without_candy['name']))
print("updated list of pokemon with eval less than 2", pokemon_with_eval_less_than_2)
print("number of pokemon's: ", len(pokemon_with_eval_less_than_2))
# Out:
# updated list of pokemon with eval less than 2 ['Bulbasaur', 'Nidoran', 'Eevee', 'Gastly', 'Geodude', 'Bellsprout', 'Machop', 'Charmander', 'Poliwag', 'Oddish', 'Nidoran', 'Abra', 'Dratini', 'Squirtle', 'Weedle', 'Pidgey', 'Caterpie', 'Voltorb', 'Seel', 'Grimer', 'Shellder', 'Drowzee', 'Krabby', 'Exeggcute', 'Magnemite', 'Cubone', 'Koffing', 'Rhyhorn', 'Horsea', 'Goldeen', 'Staryu', 'Magikarp', 'Kabuto', 'Doduo', 'Sandshrew', 'Clefairy', 'Meowth', 'Vulpix', 'Jigglypuff', 'Zubat', 'Pikachu', 'Paras', 'Venonat', 'Ponyta', 'Slowpoke', 'Psyduck', 'Mankey', 'Growlithe', 'Ekans', 'Spearow', 'Rattata', 'Tentacool', 'Diglett', 'Omanyte', 'Dugtrio', "Farfetch'd", 'Onix', 'Hitmonlee', 'Hitmonchan', 'Lickitung', 'Chansey', 'Tangela', 'Kangaskhan', 'Mr. Mime', 'Scyther', 'Jynx', 'Electabuzz', 'Magmar', 'Pinsir', 'Tauros', 'Lapras', 'Ditto', 'Jolteon', 'Porygon', 'Omastar', 'Aerodactyl', 'Snorlax', 'Articuno', 'Zapdos', 'Moltres', 'Mewtwo', 'Mew']
# number of pokemon's:  82

# %% [markdown]
# -----

# %% [markdown]
# #### New approach:

# %%
list(df[df['id']==133]['prev_evolution']) # this makes my previous logic wrong...
# Out:
# [nan]

# %%
def convert_to_list(string):
    try:
        return ast.literal_eval(string)
    except (SyntaxError, ValueError):
        return []

df['next_evolution'] = df['next_evolution'].apply(convert_to_list)

# %%
for i in range(len(df)):
    if pd.isnull(df['next_evolution']).iloc[i]:
        df.loc[i,'total_evolutions'] =0
    else:
        df.loc[i,'total_evolutions']=len(df['next_evolution'].iloc[i])

# %%
filtered_df=df[df['total_evolutions']<=2]
pokemon_with_less_than_2evolutions=len(filtered_df)
pokemon_with_less_than_2evolutions
# Out:
# 150

# %%
filtered_df
# Out:
#       id  num        name                                               img
# 0      1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png  \
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...         ...                                               ...
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                      type  height    weight             candy  candy_count
# 0     ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0  \
# 1     ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2     ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3                ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4                ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
# ..                    ...     ...       ...               ...          ...
# 146            ['Dragon']  1.80 m    3.3 kg     Dratini Candy         25.0
# 147            ['Dragon']  3.99 m   16.5 kg     Dratini Candy        100.0
# 148  ['Dragon', 'Flying']  2.21 m  210.0 kg     Dratini Candy          NaN
# 149           ['Psychic']  2.01 m  122.0 kg               NaN          NaN
# 150           ['Psychic']  0.41 m    4.0 kg               NaN          NaN
#
#              egg  spawn_chance  avg_spawns spawn_time
# 0           2 km        0.6900       69.00      20:00  \
# 1    Not in Eggs        0.0420        4.20      07:00
# 2    Not in Eggs        0.0170        1.70      11:30
# 3           2 km        0.2530       25.30      08:45
# 4    Not in Eggs        0.0120        1.20      19:00
# ..           ...           ...         ...        ...
# 146        10 km        0.3000       30.00      06:41
# 147  Not in Eggs        0.0200        2.00      11:57
# 148  Not in Eggs        0.0011        0.11      23:38
# 149  Not in Eggs        0.0000        0.00        NaN
# 150  Not in Eggs        0.0000        0.00        NaN
#
#                     multipliers                    weaknesses
# 0                        [1.58]  [Fire, Ice, Flying, Psychic]  \
# 1                    [1.2, 1.6]  [Fire, Ice, Flying, Psychic]
# 2                           NaN  [Fire, Ice, Flying, Psychic]
# 3                        [1.65]         [Water, Ground, Rock]
# 4                        [1.79]         [Water, Ground, Rock]
# ..                          ...                           ...
# 146  [1.83, 1.8399999999999999]          [Ice, Dragon, Fairy]
# 147                      [2.05]          [Ice, Dragon, Fairy]
# 148                         NaN    [Ice, Rock, Dragon, Fairy]
# 149                         NaN            [Bug, Ghost, Dark]
# 150                         NaN            [Bug, Ghost, Dark]
#
#                                         next_evolution
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...  \
# 1                 [{'num': '003', 'name': 'Venusaur'}]
# 2                                                   []
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4                [{'num': '006', 'name': 'Charizard'}]
# ..                                                 ...
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...
# 147              [{'num': '149', 'name': 'Dragonite'}]
# 148                                                 []
# 149                                                 []
# 150                                                 []
#
#                                         prev_evolution spawn_min spawn_rate
# 0                                                  NaN      1200     3.9675  \
# 1                [{'num': '001', 'name': 'Bulbasaur'}]       420      0.042
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...       690   0.004188
# 3                                                  NaN       525   1.219219
# 4               [{'num': '004', 'name': 'Charmander'}]      1140   0.001263
# ..                                                 ...       ...        ...
# 146                                                NaN       401   2.244389
# 147                [{'num': '147', 'name': 'Dratini'}]       717   0.005579
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...      1418   0.000009
# 149                                                NaN      None       None
# 150                                                NaN      None       None
#
#      total_evolutions
# 0                 2.0
# 1                 1.0
# 2                 0.0
# 3                 2.0
# 4                 1.0
# ..                ...
# 146               2.0
# 147               1.0
# 148               0.0
# 149               0.0
# 150               0.0
#
# [150 rows x 20 columns]

# %% [markdown]
# --------

# %% [markdown]
# ### Task 5: Get all Pokemon who have more than two types of capabilities

# %%
def convert_to_list(string):
    try:
        return ast.literal_eval(string)
    except (SyntaxError, ValueError):
        return []

# %%
import json

# df['type'] = df['type'].apply(ast.literal_eval)

# %%
df[df['type'].apply(len) > 2]
# Out:
# Empty DataFrame
# Columns: [id, num, name, img, type, height, weight, candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, weaknesses, next_evolution, prev_evolution, spawn_min, spawn_rate, total_evolutions]
# Index: []

# %%
df['type'].apply(len) > 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# Name: type, Length: 151, dtype: bool

# %%
# There are no pokemon more than two types of capabilities

# %% [markdown]
# ----
