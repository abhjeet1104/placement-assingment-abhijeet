# %%
import pandas as pd
import requests

# %%
url = "https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD"

df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130443 entries, 0 to 130442
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         130443 non-null  object
#  1   County                                             130440 non-null  object
#  2   City                                               130440 non-null  object
#  3   State                                              130443 non-null  object
#  4   Postal Code                                        130440 non-null  float64
#  5   Model Year                                         130443 non-null  int64
#  6   Make                                               130443 non-null  object
#  7   Model                                              130221 non-null  object
#  8   Electric Vehicle Type                              130443 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  130443 non-null  object
#  10  Electric Range                                     130443 non-null  int64
#  11  Base MSRP                                          130443 non-null  int64
#  12  Legislative District                               130138 non-null  float64
#  13  DOL Vehicle ID                                     130443 non-null  int64
#  14  Vehicle Location                                   130410 non-null  object
#  15  Electric Utility                                   130440 non-null  object
#  16  2020 Census Tract                                  130440 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 16.9+ MB

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
# 3           Clean Alternative Fuel Vehicle Eligible              75
# 4           Clean Alternative Fuel Vehicle Eligible             210
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
# 1          0                  23.0       171566447
# 2          0                  36.0         9426525
# 3          0                  36.0       211807760
# 4          0                  22.0       185810306
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-120.56916 46.58514)                                    PACIFICORP
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.40092 47.65908)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3   POINT (-122.3684 47.64586)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-122.75379 47.06316)                        PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303509e+10
# 2       5.303301e+10
# 3       5.303301e+10
# 4       5.306701e+10

# %% [markdown]
# # Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] != 'Clean Alternative Fuel Vehicle Eligible'][['Make','Model','Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility']]
# Out:
#           Make    Model                   Electric Vehicle Type  \
# 6         FORD   FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 7         AUDI     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 8         FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 11       TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 14        FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# ...        ...      ...                                     ...
# 130437     BMW     530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 130438   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 130439  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 130440   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 130442   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility
# 6                   Not eligible due to low battery range
# 7                   Not eligible due to low battery range
# 8                   Not eligible due to low battery range
# 11      Eligibility unknown as battery range has not b...
# 14                  Not eligible due to low battery range
# ...                                                   ...
# 130437              Not eligible due to low battery range
# 130438  Eligibility unknown as battery range has not b...
# 130439  Eligibility unknown as battery range has not b...
# 130440  Eligibility unknown as battery range has not b...
# 130442  Eligibility unknown as battery range has not b...
#
# [69892 rows x 4 columns]

# %% [markdown]
# # Get all TESLA cars with the model year, and model type made in Bothell City

# %%
df[(df['Make']== 'TESLA') & (df['City'] == 'Bothell')][['Model', 'Model Year']]
# Out:
#           Model  Model Year
# 39      MODEL 3        2020
# 217     MODEL 3        2022
# 218     MODEL Y        2022
# 222     MODEL 3        2018
# 292     MODEL X        2017
# ...         ...         ...
# 129778  MODEL 3        2019
# 129954  MODEL 3        2021
# 129976  MODEL S        2014
# 130295  MODEL 3        2022
# 130392  MODEL 3        2018
#
# [2407 rows x 2 columns]

# %% [markdown]
# # Get all the cars that have an electric range of more than 100, and were made after 2015

# %%
df.head(3)
# Out:
#    VIN (1-10)  County     City State  Postal Code  Model Year   Make    Model  \
# 0  5YJXCAE26J  Yakima   Yakima    WA      98908.0        2018  TESLA  MODEL X
# 1  JHMZC5F37M  Kitsap  Poulsbo    WA      98370.0        2021  HONDA  CLARITY
# 2  5YJ3E1EB0K    King  Seattle    WA      98199.0        2019  TESLA  MODEL 3
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
# 1          0                  23.0       171566447
# 2          0                  36.0         9426525
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-120.56916 46.58514)                                    PACIFICORP
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.40092 47.65908)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303509e+10
# 2       5.303301e+10

# %%
df[(df['Model Year'] > 2015 ) & (df['Electric Range'] > 100)]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# 0        TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 2        TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 4        TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 12       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 13       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# ...        ...      ...                             ...
# 130417   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130428  NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 130432   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130436   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 130441   TESLA  MODEL X  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                Clean Alternative Fuel Vehicle Eligible             238
# 2                Clean Alternative Fuel Vehicle Eligible             220
# 4                Clean Alternative Fuel Vehicle Eligible             210
# 12               Clean Alternative Fuel Vehicle Eligible             308
# 13               Clean Alternative Fuel Vehicle Eligible             322
# ...                                                  ...             ...
# 130417           Clean Alternative Fuel Vehicle Eligible             291
# 130428           Clean Alternative Fuel Vehicle Eligible             151
# 130432           Clean Alternative Fuel Vehicle Eligible             291
# 130436           Clean Alternative Fuel Vehicle Eligible             215
# 130441           Clean Alternative Fuel Vehicle Eligible             293
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                  14.0       141151601
# 2               0                  36.0         9426525
# 4               0                  22.0       185810306
# 12              0                  22.0         2135486
# 13              0                  22.0       124645363
# ...           ...                   ...             ...
# 130417          0                  29.0       112591538
# 130428          0                  24.0       290405174
# 130432          0                  34.0       112734723
# 130436          0                  42.0       103521302
# 130441          0                  10.0       102834938
#
#                                      Vehicle Location  \
# 0                         POINT (-120.56916 46.58514)
# 2                         POINT (-122.40092 47.65908)
# 4                         POINT (-122.75379 47.06316)
# 12                        POINT (-122.82324 47.04437)
# 13                        POINT (-122.75379 47.06316)
# ...                                               ...
# 130417                    POINT (-122.46495 47.16778)
# 130428  POINT (-123.09968999999995 48.08137000000005)
# 130432                     POINT (-122.4573 47.44929)
# 130436                    POINT (-122.74888 48.99404)
# 130441                    POINT (-122.40049 48.23986)
#
#                                          Electric Utility  2020 Census Tract
# 0                                              PACIFICORP       5.307700e+10
# 2            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# 12                                 PUGET SOUND ENERGY INC       5.306701e+10
# 13                                 PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 130417  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 130428  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.300900e+10
# 130432      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 130436  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307301e+10
# 130441  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
#
# [34066 rows x 17 columns]

# %% [markdown]
# # Draw plots to show the distribution between city and electric vehicle type

# %%
df.head(2)
# Out:
#    VIN (1-10)  County     City State  Postal Code  Model Year   Make    Model  \
# 0  5YJXCAE26J  Yakima   Yakima    WA      98908.0        2018  TESLA  MODEL X
# 1  JHMZC5F37M  Kitsap  Poulsbo    WA      98370.0        2021  HONDA  CLARITY
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
# 1          0                  23.0       171566447
#
#               Vehicle Location        Electric Utility  2020 Census Tract
# 0  POINT (-120.56916 46.58514)              PACIFICORP       5.307700e+10
# 1  POINT (-122.64681 47.73689)  PUGET SOUND ENERGY INC       5.303509e+10

# %%
df['Electric Vehicle Type'].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
import seaborn as sns

# %%
list_of_cities = df['City'].unique()
print(list_of_cities)
print(len(list_of_cities))
# Out:
# ['Yakima' 'Poulsbo' 'Seattle' 'Lacey' 'Olympia' 'Tumwater' 'Rochester'
#  'Bremerton' 'Bainbridge Island' 'Everett' 'Leavenworth' 'Mill Creek'
#  'Snohomish' 'Mount Vernon' 'Arlington' 'Lake Stevens' 'Burlington'
#  'Anacortes' 'Edmonds' 'Bothell' 'Sultan' 'Spokane' 'Pullman' 'Yelm'
#  'Port Orchard' 'Palouse' 'Monroe' 'Marysville' 'Mukilteo' 'Brier'
#  'Lynnwood' 'Kettle Falls' 'Orondo' 'Selah' 'Oak Harbor' 'Clinton'
#  'Cheney' 'Granite Falls' 'Renton' nan 'Walla Walla' 'Freeland' 'Kent'
#  'Redmond' 'Vancouver' 'Tukwila' 'Federal Way' 'Kirkland' 'Bellevue'
#  'Battle Ground' 'Duvall' 'Brush Prairie' 'Sammamish' 'Burien' 'Auburn'
#  'Bingen' 'Camas' 'Issaquah' 'Shoreline' 'Covington' 'Woodinville'
#  'Longview' 'Olalla' 'Normandy Park' 'Port Townsend' 'North Bend'
#  'Seabeck' 'Medina' 'Maple Valley' 'Newcastle' 'Des Moines' 'Ridgefield'
#  'Washougal' 'Kelso' 'Kenmore' 'Nine Mile Falls' 'Moxee' 'Seatac'
#  'La Center' 'Lake Forest Park' 'Sunnyside' 'Kalama' 'Grandview' 'Sequim'
#  'Beaux Arts' 'Silverdale' 'Quilcene' 'Woodland' 'Indianola'
#  'Camano Island' 'Keyport' 'Tieton' 'Brinnon' 'Mercer Island'
#  'Black Diamond' 'Port Hadlock' 'Rainier' 'Kingston' 'Suquamish'
#  'Castle Rock' 'Clyde Hill' 'Port Ludlow' 'Enumclaw' 'Tenino' 'Goldendale'
#  'Coupeville' 'Nordland' 'White Salmon' 'Silverlake' 'Ariel' 'Mabton'
#  'Pacific' 'Yacolt' 'Woodway' 'Zillah' 'Toutle' 'Port Angeles' 'Ryderwood'
#  'Algona' 'Bucoda' 'Stanwood' 'Wapato' 'Tulalip' 'Forks' 'Amboy' 'Granger'
#  'Toppenish' 'Carrolls' 'Mountlake Terrace' 'Langley' 'Colville' 'Milton'
#  'Naches' 'Snoqualmie' 'Chewelah' 'Hunts Point' 'Yarrow Point' 'Gold Bar'
#  'Centralia' 'Chimacum' 'Carnation' 'Hansville' 'Skykomish' 'Darrington'
#  'Gig Harbor' 'Union Gap' 'Index' 'Deer Park' 'Lakewood' 'Tacoma'
#  'Bellingham' 'Olga' 'Allyn' 'South Hill' 'Wenatchee' 'Fircrest'
#  'Valleyford' 'Methow' 'Lynden' 'Puyallup' 'Anderson Island' 'Cle Elum'
#  'Moses Lake' 'Omak' 'Spokane Valley' 'Fife' 'Vashon' 'Shelton' 'Richland'
#  'Pasco' 'Orting' 'Kennewick' 'Joint Base Lewis Mcchord' 'East Wenatchee'
#  'Ocean Shores' 'Manson' 'Royal City' 'Snowden' 'College Place' 'Prosser'
#  'Sumner' 'Goshen' 'Ellensburg' 'Belfair' 'Trout Lake' 'Carson' 'Elma'
#  'Hoodsport' 'Edgewood' 'Eastsound' 'Chelan' 'Eatonville' 'Entiat'
#  'Friday Harbor' 'Fall City' 'Sedro Woolley' 'Bonney Lake' 'Mccleary'
#  'Veradale' 'Randle' 'Ferndale' 'Lopez Island' 'Hoquiam' 'Newport'
#  'Spangle' 'Stevenson' 'Buckley' 'Point Roberts' 'Rosalia' 'Taholah'
#  'Blaine' 'Montesano' 'Graham' 'Lakebay' 'Underwood' 'Chehalis'
#  'Clarkston' 'Union' 'Fox Island' 'La Conner' 'Rock Island'
#  'West Richland' 'Aberdeen' 'Parkland' 'Pacific Beach' 'Liberty Lake'
#  'Medical Lake' 'Benton City' 'Newman Lake' 'Grapeview' 'Spanaway'
#  'Dupont' 'Sedro-Woolley' 'Naselle' 'Husum' 'Sumas' 'Quincy' 'Endicott'
#  'Murdock' 'Winlock' 'Mica' 'Omaha' 'Winthrop' 'Greenacres' 'Norristown'
#  'Packwood' 'Bow' 'Greenbank' 'Toledo' 'Lummi Island' 'Long Beach'
#  'Steilacoom' 'Mead' 'Morton' 'Tempe' 'Twisp' 'Ilwaco' 'Easton' 'Westport'
#  'Chattaroy' 'Airway Heights' 'Oroville' 'Lopez Is' 'Lake Tapps'
#  'Neah Bay' 'Onalaska' 'Highland Park' 'Peshastin' 'North Bonneville'
#  'Colbert' 'Evans' 'Fairchild Air Force Base' 'Lind' 'Cathlamet'
#  'Clallam Bay' 'Frances' 'Elk' 'Othello' 'Clearlake' 'Washington'
#  'Raymond' 'Okanogan' 'Reardan' 'Mossyrock' 'Mesa' 'Seaview' 'Ephrata'
#  'Silver Creek' 'Ritzville' 'Mineral' 'Roy' 'Everson' 'Burbank'
#  'Annapolis' 'Henrico' 'Lilliwaup' 'Glacier' 'Harrington' 'Tahuya'
#  'Cashmere' 'Garfield' 'Outlook' 'Las Vegas' 'Buena Park' 'Wilbur'
#  'Ronald' 'Sekiu' 'Roslyn' 'Cosmopolis' 'Mattawa' 'Ocean Park' 'Ashford'
#  'Tonasket' 'Salkum' 'Maple Falls' 'Riverside' 'Ethel' 'Dayton' 'Colfax'
#  'Lamont' 'Hatton' 'Ridgecrest' 'Mazama' 'Shaw Island' 'Brewster'
#  'Kittitas' 'San Rafael' 'Vaughn' 'Usk' 'Waitsburg' 'Asotin' 'Grayland'
#  'Bz Corner' 'South Prairie' 'Vantage' 'Eltopia' 'University Place'
#  'Salem' 'Otis Orchards' 'Carbonado' 'Soap Lake' 'Bay Center' 'Satsop'
#  'Hartline' 'Carlton' 'Curlew' 'Snoqualmie Pass' 'Rockport' 'San Antonio'
#  'Glenoma' 'Nooksack' 'Raeford' 'Vader' 'Libertyville' 'Cheyenne'
#  'Seven Bays' 'Malaga' 'Kapowsin' 'Addy' 'Pittsburg' 'Prescott'
#  'Electric City' 'Touchet' 'Smiths Station' 'Hamilton' 'Orcas Is'
#  'Uniontown' 'Marlin' 'Waterville' 'Decatur' 'Republic' 'Rockford'
#  'Connell' 'Rosburg' 'Menlo' 'Acme' 'Waldron' 'Platte City' 'Lebam'
#  'Latah' 'Rice' 'Roosevelt' 'Fort Bragg' 'Beaver' 'Pomeroy' 'Aldie'
#  'San Diego' 'Oakville' 'Longbranch' 'Skamokawa' 'Greenfield Center'
#  'Wilkeson' 'Curtis' 'Gardena' 'Copalis Crossing' 'Gambrills' 'Wishram'
#  'Cinebar' 'Santa Cruz' 'Warden' 'Grays River' 'El Paso' 'Cusick'
#  'Oceanside' 'Bridgeport Bar' 'Coulee City' 'Santa Clara' 'Stratford'
#  'Silver Spring' 'Little Elm' 'Frederick' 'Goldsboro' 'North Cove'
#  'Edwall' 'Wildomar' 'Valley' 'Dallesport' 'Ravensdale' 'Cowiche'
#  'Glenwood' 'Davenport' 'Preston' 'Edgewater' 'Lyle' 'Loon Lake' 'Custer'
#  'Concrete' 'Chinook' 'Oysterville' 'Tokeland' 'Springfield' 'Danville'
#  'Ruston' 'Hunters' 'Portland' 'Sacramento' 'Pe Ell' 'Lincoln'
#  'Silver Lake' 'Westminster' 'Moclips' 'Wichita Falls' 'Surfside'
#  'Nahcotta' 'Deming' 'Pateros' 'Gifford' 'Fruitland' 'San Mateo' 'Clayton'
#  'Smith Creek' 'Fayetteville' 'Menifee' 'Lemoore' 'Deer Meadows'
#  'Fort Irwin' 'Deer Harbor' 'White Swan' 'St John' 'Walla Walla Co'
#  'South Bend' 'Cougar' 'Grand Coulee' 'Klickitat' 'Lithia' 'Springdale'
#  'Lancaster' 'Baring' 'Inchelium' 'Thorp' 'Maryhill' 'Fredericksburg'
#  'Amanda Park' 'Mansfield' 'Alderdale' 'Sprague' 'Biloxi' 'Coulee Dam'
#  'Copalis Beach' 'Phoenix' 'Ford' 'Malott' 'Alexandria' 'McCleary'
#  'Laughlin' 'Lompoc' 'Wahkiacus' 'Odessa' 'Belle Chasse' 'Incorporated'
#  'Suwanee' 'Norfolk' 'Lincoln City' 'Waterford' 'Tekoa' 'Ewa Beach'
#  'Sumter' 'Santa Ana' 'Medford' 'Port Gamble' 'Dickinson' 'Odenton'
#  'Asheboro' 'Germantown' 'Chula Vista' 'Saint Jacob' 'Watertown'
#  'Little Rock' 'Waldorf' 'Staten Island' 'Beaufort' 'Killeen' 'Plymouth'
#  'Mcchord Afb' 'Goodyear' 'Dover' 'Irvine' 'Gatesville' 'Wylie' 'Moraga'
#  'Ventura' 'Vienna' 'Keedysville' 'Timnath' 'Suffolk' 'Minneapolis'
#  'Cupertino' 'San Jose' 'Leesville' 'Quinault' 'Herndon' 'Napa' 'Madison'
#  'Saratoga Springs' 'Scottsdale' 'Berkeley' 'Chesapeake Beach' 'Eugene'
#  'Burke' 'Salt Lake City' 'Summerville' 'Fort Leavenworth'
#  'Harker Heights' 'Charleston Afb' 'Parker' 'Newport Beach' 'Chesapeake'
#  'Marblemount' 'Coronado' 'Hanscom Afb' 'Fairfield' 'Kailua' 'Chelmsford'
#  'Las Cruces' 'Vacaville' 'San Clemente' 'Mount Pleasant'
#  'Andrews Air Force Base' 'Clarksville' 'Slidell' 'Skokie' 'Mechanicsburg'
#  'Haddonfield' 'Bell Hill' 'Indio' 'Cincinnati' 'South Range' 'Rosamond'
#  'Augusta' 'Belleville' 'Worley' 'Hughesville' 'Rayville' 'Sarasota'
#  'Newark' 'Fort Lauderdale' 'Los Angeles' 'Pros' 'Seaside'
#  'South Cle Elum' 'Altus' 'Warner Robins' 'Twentynine Palms'
#  'Upper Marlboro' 'Aiea' 'Bedford' 'Kekaha' 'Artondale' 'Mystic' 'Anthem'
#  'Palo Alto' 'Portsmouth' 'Canoga Park' 'Santa Rosa' 'Trinidad'
#  'Junction City' 'Potomac' 'Alhambra' 'Nespelem' 'Fremont' 'Petoskey'
#  'Prosper' 'Southern Pines' 'Mountain Home Afb' 'Englewood' 'Conyers'
#  'Stafford' 'Okatie' 'Colorado Springs' 'Lansing' 'North Las Vegas'
#  'Sheridan' 'Virginia Beach' 'Weslaco' 'Arnold' 'Chandler' 'Pawcatuck'
#  'Tumtum' 'Mountain View' 'Mccutcheon Field' 'Newport News' 'Kenn'
#  'Chevy Chase' 'Temecula' 'Benicia' 'Mascoutah' 'Dryden' 'Avalon' 'Sonoma'
#  'Fort Wayne' 'Bridgeport' 'Cathedral City' 'Fort George G Meade'
#  'Felts Mills' 'Southlake' 'Lexington Park' 'Travis Afb' 'Apple Valley'
#  'Colton' 'Fort Walton Beach' 'Carmel By The Sea' 'Joint Base Mdl'
#  'Gaithersburg' 'Arlington Heights' 'Old Lyme' 'Fort Campbell' 'Dallas'
#  'Spring Lake' 'Jericho' 'Longmont' 'Orchards' 'Napavine' 'Middletown'
#  'Fairbanks' 'Honolulu' 'Corvallis' 'Aurora']
# 657

# %%
df.groupby("City")["Electric Vehicle Type"].count()
# Out:
# City
# Aberdeen          115
# Acme                7
# Addy                2
# Aiea                1
# Airway Heights     18
#                  ...
# Yacolt             32
# Yakima            471
# Yarrow Point      126
# Yelm              197
# Zillah             23
# Name: Electric Vehicle Type, Length: 656, dtype: int64

# %%
top_20 = df.groupby("City")["Electric Vehicle Type"].count().sort_values(ascending=False)[:20]

# %%
x = list(dict(top_20).keys())
y = list(dict(top_20).values())

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.barplot(x=x, y=y)
# Out:
# <Axes: >
